# %%
#사고부위 

import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
import numpy as np
embedder = SentenceTransformer("jhgan/ko-sroberta-multitask")
df9=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df9.csv")
# Out:
# /tmp/ipykernel_24232/2916468895.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df9=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df9.csv")

# %%
df9.drop(['Unnamed: 0'], axis=1, inplace=True)
df9
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
구분류_사고부위 = df9['사고부위'].unique()
for part in 구분류_사고부위:
    print(part)
# Out:
# 입(구강/혀),기타
# 발목
# 손목
# 손가락
# 기타
# 아래팔,팔꿈치
# 이마
# 종아리
# 코,입(구강/혀),이마,턱,볼
# 발가락
# 배
# 아래팔,무릎
# 손
# 발
# 두피
# 눈
# 코
# 턱
# 눈,볼,무릎
# 손,무릎
# 무릎
# 팔꿈치
# 입(구강/혀)
# 위팔,아래팔
# 허리
# 눈,이마
# 엉덩이,넓적다리(허벅지),무릎,종아리,발,발가락,발목
# 흉부(가슴),넓적다리(허벅지),내장기관
# 두피,이마
# 손가락,발목
# 아래팔,팔꿈치,손목
# 치아
# 허리,위팔,엉덩이,발목
# 귀
# 볼
# 입(구강/혀),치아
# 어깨
# 무릎,종아리,발,발목
# 입(구강/혀),턱,팔꿈치,무릎
# 눈,코,이마,턱,볼
# 흉부(가슴),손가락
# 목
# 흉부(가슴)
# 눈,코,볼
# 아래팔
# 위팔,아래팔,팔꿈치
# 코,입(구강/혀),치아
# 무릎,종아리,발목
# 목,허리,손,손가락,손목
# 내장기관,기타
# 발,발가락
# 입(구강/혀),치아,무릎,종아리
# 치아,손목
# 아래팔,손목
# 손,손가락
# 위팔
# 목,어깨,위팔,겨드랑이
# 손목,무릎
# 어깨,손목
# 입(구강/혀),턱,치아
# 눈,기타
# 두피,허리,팔꿈치
# 이마,볼
# 입(구강/혀),턱,아래팔
# 눈,코
# 발,발가락,발목
# 무릎,발목
# 코,볼
# 손,손목
# 종아리,발,발가락,발목
# 두피,어깨
# 두피,턱
# 넓적다리(허벅지)
# 어깨,무릎
# 배,넓적다리(허벅지)
# 코,기타
# 흉부(가슴),허리
# 턱,손,손목,무릎,종아리
# 이마,아래팔,팔꿈치,손목
# 턱,아래팔
# 귀,팔꿈치
# 이마,턱,볼
# 허리,무릎
# 코,이마
# 손,손가락,손목
# 이마,어깨,무릎
# 이마,턱
# 엉덩이,넓적다리(허벅지),종아리
# 손,손가락,무릎
# 눈,귀,어깨
# 발,발목
# 등
# 두피,기타
# 아래팔,팔꿈치,무릎
# 엉덩이
# 등,신경계
# 입(구강/혀),턱
# 두피,귀,내장기관
# 두피,팔꿈치,무릎
# 발가락,발목
# 코,치아
# 아래팔,팔꿈치,손,무릎
# ...

# %%
#aa=row['사고부위'].count(',')

# %%
for index, row in df9.iterrows():
    if "," in row['사고부위']:
        df9.at[index, '신분류_사고부위'] = '복합부위-복합부위-복합부위'


#for index, row in df9.iterrows():
#    aa=row['사고부위'].count(',')
#    if aa>=1:
#        df9.at[index, '신분류_사고부위'] = '복합부위-복합부위-복합부위'

# %%
df9
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
test=df9[['사고부위','신분류_사고부위']]

# %%
test
# Out:
#               사고부위        신분류_사고부위
# 0       입(구강/혀),기타  복합부위-복합부위-복합부위
# 1               발목             NaN
# 2               발목             NaN
# 3               손목             NaN
# 4              손가락             NaN
# ...            ...             ...
# 545963          무릎             NaN
# 545964          치아             NaN
# 545965           발             NaN
# 545966           발             NaN
# 545967           발             NaN
#
# [545968 rows x 2 columns]

# %%
frequency = df9['신분류_사고부위'].value_counts()
print(frequency)
frequency2 = df9['사고부위'].value_counts()
print(frequency2)
#frequency2.to_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/frequency2.csv",index=True)
# Out:
# 신분류_사고부위
# 복합부위-복합부위-복합부위    37822
# Name: count, dtype: int64
# 사고부위
# 발                                   71840
# 손                                   68919
# 손가락                                 56296
# 발목                                  53076
# 무릎                                  30691
#                                     ...
# 어깨,아래팔,손,손가락,엉덩이,발,발목                   1
# 어깨,위팔,아래팔,팔꿈치,손,손목,엉덩이,넓적다리(허벅지)        1
# 코,이마,턱,목,위팔                             1
# 흉부(가슴),허리,손,손목,무릎,발목                    1
# 허리,어깨,위팔,팔꿈치                            1
# Name: count, Length: 3467, dtype: int64

# %%
#df9.to_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df10.csv",index=True)

# %%
##############################################################################################
##############################################################################################
##############################################################################################
##############################################################################################
##################################여기부터야!##################################################

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
import numpy as np
embedder = SentenceTransformer("jhgan/ko-sroberta-multitask")
df10=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df10.csv")
# Out:
# /tmp/ipykernel_6036/2525325051.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df10=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df10.csv")

# %%
df10.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df10
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
n사고장소 = df10['신분류_사고장소'].unique()
print(n사고장소)
# Out:
# ['교내-체육·집회공간-운동장' '교내-체육·집회공간-기타 체육·집회공간' '교내-체육·집회공간-강당(체육관)'
#  '교내-체육·집회공간-놀이터' nan '교내-교수학습 및 학습지원공간-일반(교과)교실' '교내-기타 교내-기타 교내'
#  '교내-교수학습 및 학습지원공간-특별교실(과학실)' '교내-공용공간-복도' '교내-공용공간-계단' '교내-기타 교내-급식실'
#  '교내-교수학습 및 학습지원공간-학습지원공간' '교내-교수학습 및 학습지원공간-특별교실(과학실 외)' '교내-보건·위생공간-화장실'
#  '교외-문화·체육공간-실‧내외 체육시설' '교외-문화·체육공간-청소년 수련 시설' '교내-기타교내-기숙사'
#  '교외-교통구역(스쿨존 내)-교통수단 안' '교내-공용공간-기타 공용공간' '교외-기타 교외-기타 교외' '교내-공용공간-현관'
#  '교외-교통구역(스쿨존 외)-교통수단 안']

# %%
n사고장소 = df10['신분류_사고장소'].value_counts(dropna=False)
n사고장소
# Out:
# 신분류_사고장소
# 교내-체육·집회공간-강당(체육관)              140899
# 교내-체육·집회공간-운동장                  137835
# 교내-교수학습 및 학습지원공간-일반(교과)교실        76104
# 교내-공용공간-계단                       40539
# NaN                              39028
# 교내-공용공간-복도                       32388
# 교내-기타 교내-기타 교내                   18024
# 교내-체육·집회공간-기타 체육·집회공간            15996
# 교내-체육·집회공간-놀이터                   11626
# 교외-문화·체육공간-실‧내외 체육시설              6012
# 교내-보건·위생공간-화장실                    5924
# 교내-기타 교내-급식실                      5286
# 교내-교수학습 및 학습지원공간-특별교실(과학실 외)      4339
# 교내-교수학습 및 학습지원공간-특별교실(과학실)        3984
# 교내-공용공간-현관                        3456
# 교내-기타교내-기숙사                       1886
# 교내-교수학습 및 학습지원공간-학습지원공간           1058
# 교내-공용공간-기타 공용공간                    699
# 교외-문화·체육공간-청소년 수련 시설               644
# 교외-교통구역(스쿨존 외)-교통수단 안              155
# 교외-교통구역(스쿨존 내)-교통수단 안               65
# 교외-기타 교외-기타 교외                      21
# Name: count, dtype: int64

# %%
n사고시간 = df10['신분류_사고시간'].unique()
n사고시간
# Out:
# array(['교육과정-교과(초·중·고)-체육-체육', nan, '교육과정-비교과(공통)-특별활동시간-수련활동, 수학여행',
#        '기타 교육활동시간(공통)-학교체류-식사시간(간식 포함)', '기타 교육활동시간(공통)-학교체류-방과후과정',
#        '교육과정-비교과(공통)-창의적체험-동아리활동', '교육과정-교과(초·중·고)-이론수업-이론수업',
#        '교육과정-비교과(공통)-특별활동시간-기타 특별활동시간', '기타 교육활동시간(공통)-학교체류-쉬는시간',
#        '교육과정-교과(초·중·고)-실험/실습-실과(기술·가정)', '기타 교육활동시간(공통)-학교체류-기타 학교체류',
#        '교육과정-비교과(공통)-특별활동시간-학교축제', '기타 교육활동시간(공통)-등·하교-하교',
#        '기타 교육활동시간(공통)-그 밖의 교육활동 시간-그 밖의 교육활동 시간',
#        '교육과정-비교과(공통)-특별활동시간-체육대회', '기타 교육활동시간(공통)-등·하교-등교',
#        '교육과정-교과(초·중·고)-실험/실습-기타(음악, 미술 등)', '교육과정-교과(초·중·고)-실험/실습-과학',
#        '교육과정-비교과(공통)-창의적 체험-자율활동', '교육과정-비교과(공통)-특별활동시간-현장학습',
#        '교육과정-비교과(공통)-특별활동시간-경기출전', '교육과정-비교과(공통)-창의적 체험-봉사활동'],
#       dtype=object)

# %%
n사고시간 = df10['신분류_사고시간'].value_counts(dropna=False)
n사고시간
# Out:
# 신분류_사고시간
# 교육과정-교과(초·중·고)-체육-체육                       186124
# 기타 교육활동시간(공통)-학교체류-식사시간(간식 포함)             101500
# 기타 교육활동시간(공통)-학교체류-쉬는시간                     65730
# NaN                                         47142
# 교육과정-교과(초·중·고)-이론수업-이론수업                    24894
# 기타 교육활동시간(공통)-학교체류-방과후과정                    18420
# 기타 교육활동시간(공통)-등·하교-하교                       17377
# 교육과정-비교과(공통)-특별활동시간-기타 특별활동시간               13599
# 교육과정-비교과(공통)-창의적체험-동아리활동                    12745
# 교육과정-비교과(공통)-특별활동시간-체육대회                    12145
# 기타 교육활동시간(공통)-등·하교-등교                        8825
# 기타 교육활동시간(공통)-학교체류-기타 학교체류                   7076
# 교육과정-비교과(공통)-특별활동시간-경기출전                     6813
# 교육과정-교과(초·중·고)-실험/실습-실과(기술·가정)               4511
# 교육과정-비교과(공통)-특별활동시간-현장학습                     4467
# 교육과정-교과(초·중·고)-실험/실습-기타(음악, 미술 등)            3767
# 교육과정-비교과(공통)-창의적 체험-자율활동                     3119
# 교육과정-교과(초·중·고)-실험/실습-과학                      2921
# 교육과정-비교과(공통)-특별활동시간-수련활동, 수학여행               1760
# ...

# %%
n사고당시활동 = df10['신분류_사고당시활동'].value_counts(dropna=False)
n사고당시활동
# Out:
# 신분류_사고당시활동
# 이동-걷기/뛰기, 오르내리기-걷기/뛰기, 오르내리기    92406
# NaN                             84020
# 스포츠활동-구기-축구                     74366
# 일상활동-장난, 놀이-장난, 놀이              74159
# 스포츠활동-구기-농구                     54632
# 스포츠활동-구기-피구                     37016
# 일상활동-식사-식사                      27458
# 스포츠활동-구기-배구                     16115
# 스포츠활동-구기-기타 구기                  15902
# 스포츠활동-기타 스포츠활동-기타 스포츠 활동        15782
# 스포츠활동-라켓 스포츠-배드민턴               11523
# 스포츠활동-육상-달리기                    10329
# 스포츠활동-체조·무용·매트운동-매트운동            6786
# 스포츠활동-구기-야구                      6364
# 스포츠활동-육상-뜀뛰기                     3238
# 스포츠활동-무도-태권도, 유도, 합기도            2971
# 스포츠활동-육상-기타 육상                   2473
# 스포츠활동-바퀴달린 무동력스포츠-사이클            2285
# 스포츠활동-라켓 스포츠-탁구                  2000
# 스포츠활동-체조·무용·매트운동-무용(댄스 포함)       1968
# 스포츠활동-육상-장애물                     1655
# 스포츠활동-수중-수영                       965
# 스포츠활동-무도-기타 무도                    955
# 기타-싸움-싸움                          365
# ...

# %%
n매개물 = df10['신분류_매개물'].value_counts(dropna=False)
n매개물
# Out:
# 신분류_매개물
# NaN                         447372
# 기구(도구,기계 등)-운동기구-기타 운동기구     82965
# 기구(도구,기계 등)-문구류-칼‧가위         11033
# 기타-고온의 물체/물질-고온의 물체/물질        4598
# Name: count, dtype: int64

# %%
n사고형태 = df10['신분류_사고형태'].value_counts(dropna=False)
n사고형태
# Out:
# 신분류_사고형태
# NaN                                                       187434
# 둔탁한 힘에 의한 사고-낙상-넘어짐                                       118660
# 둔탁한 힘에 의한 사고-부딪힘(교통사고 포함)-고정된 물체와의 부딪힘                     92753
# 둔탁한 힘에 의한 사고-부딪힘(교통사고 포함)-사람과의 부딪힘                         46375
# 기타 손상 사고-그 밖의 손상 사고-그 밖의 손상 사고                             34852
# 둔탁한 힘에 의한 사고-낙상-1미터 미만의 높이에서 떨어짐                           31090
# 관통/침투 하는 힘에 의한 사고-긁힘·베임·절단·찔림-긁힘, 찔림                       22142
# 열기(전기 포함) 또는 냉기에 의한 사고-열, 전기에 의한 손상-고온의 물체‧물질 접촉‧흡입‧섭취      6182
# 둔탁한 힘에 의한 사고-끼임·눌림-물체 사이에 끼임·눌림                             3268
# 관통/침투 하는 힘에 의한 사고-긁힘·베임·절단·찔림-동물에게 물림                       1075
# 기타 손상 사고-화학물질 노출-화학물질 접촉‧흡입·섭취                              1009
# 기타 손상 사고-식중독 및 이물질 섭취, 접촉-이물질 섭취로 인한 질병                      359
# 기타 손상 사고-식중독 및 이물질 섭취, 접촉-이물질 접촉에 의한 피부염                     277
# 둔탁한 힘에 의한 사고-부딪힘(교통사고 포함)-교통사고                               271
# ...

# %%
n사고부위 = df10['신분류_사고부위'].value_counts(dropna=False)
n사고부위
# Out:
# 신분류_사고부위
# NaN               508146
# 복합부위-복합부위-복합부위     37822
# Name: count, dtype: int64

# %%
신분류_사고장소_df=df10[df10['신분류_사고장소'].isna()]

# %%
신분류_사고장소_df
# Out:
#             id               사고번호 사고자구분       사고장소       사고시간
# 7            8  S-20220613-087751  일반학생    교외활동/기타       수학여행  \
# 8            9  S-20220707-094760  일반학생    교외활동/기타       수학여행
# 9           10  S-20220720-098301  일반학생    교외활동/기타       수학여행
# 10          11  S-20220916-105353  일반학생    교외활동/기타       수학여행
# 11          12  S-20220929-108263  일반학생    교외활동/기타       점심시간
# ...        ...                ...   ...        ...        ...
# 545861  545674       2018-0144698  일반학생       등하교길         등교
# 545876  545689       2018-0144733  일반학생         기타       휴식시간
# 545894  545707       2018-0144777  일반학생         기타  수업시간 - 기타
# 545927  545740       2018-0144890  일반학생       등하교길         등교
# 545965  545778       2018-0145074  일반학생  부속시설 - 기타       체육시간
#
#                     사고부위            사고형태                               매개물
# 7                     이마       미끄러짐-아스팔트                    자연(사람/동물/식물 등)  \
# ...

# %%
신분류_사고장소_df.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/신분류_사고장소_df.csv', encoding='utf-8', index=False)

# %%
신분류_사고시간_df=df10[df10['신분류_사고시간'].isna()]
신분류_사고시간_df
# Out:
#             id          사고번호 사고자구분     사고장소        사고시간     사고부위
# 2            3  2022-0306043  일반학생      운동장          기타       발목  \
# 6            7  2022-0378848  일반학생     놀이시설        일반수업  아래팔,팔꿈치
# 27          28  2021-0125554  일반학생     놀이시설        체육시간        턱
# 38          39  2021-0219513  일반학생       복도        일반수업        눈
# 65          66  2022-0247051  일반학생     일반교실        일반수업        눈
# ...        ...           ...   ...      ...         ...      ...
# 545881  545694  2018-0144748  일반학생       복도        조회시간        코
# 545894  545707  2018-0144777  일반학생       기타   수업시간 - 기타        발
# 545900  545713  2018-0144798  일반학생  강당(체육관)        일반수업       이마
# 545907  545720  2018-0144835  일반학생     일반교실  방과후 교실(활동)        눈
# 545933  545746  2018-0144907  일반학생     일반교실  방과후 교실(활동)        발
#
#                     사고형태                               매개물  사고당시활동
# 2                  넘어짐-흙                    자연(사람/동물/식물 등)      기타  \
# ...

# %%
신분류_사고시간_df.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/신분류_사고시간_df.csv', encoding='utf-8', index=False)

# %%
신분류_사고당시활동_df=df10[df10['신분류_사고당시활동'].isna()]
신분류_사고당시활동_df
# Out:
#             id          사고번호 사고자구분     사고장소       사고시간        사고부위
# 0            1  2022-0291538  일반학생      운동장       체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생      운동장       체육시간          발목
# 2            3  2022-0306043  일반학생      운동장         기타          발목
# 4            5  2022-0379283  일반학생  강당(체육관)       체육시간         손가락
# 5            6  2022-0383474  일반학생      운동장       체육시간          기타
# ...        ...           ...   ...      ...        ...         ...
# 545942  545755  2018-0144945  일반학생     일반교실       일반수업           손
# 545943  545756  2018-0144952  일반학생  강당(체육관)  학교행사 - 기타        아래다리
# 545946  545759  2018-0144957  일반학생     일반교실       휴식시간          두피
# 545953  545766  2018-0145007  일반학생     일반교실       일반수업          이마
# 545954  545767  2018-0145011  일반학생     일반교실       일반수업           손
#
#                     사고형태                             매개물  사고당시활동
# 0               넘어짐-콘크리트                 건물(문/창문/바닥/벽 등)      기타  \
# ...

# %%
신분류_사고당시활동_df.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/신분류_사고당시활동_df.csv', encoding='utf-8', index=False)

# %%
신분류_매개물_df=df10[df10['신분류_매개물'].isna()]
신분류_매개물_df
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545962  545775  2018-0145062  일반학생         복도  휴식시간           발
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                             매개물       사고당시활동
# 0               넘어짐-콘크리트                 건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
신분류_매개물_df.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/신분류_매개물_df.csv', encoding='utf-8', index=False)

# %%
신분류_사고형태_df=df10[df10['신분류_사고형태'].isna()]
신분류_사고형태_df
# Out:
#             id          사고번호 사고자구분  사고장소        사고시간        사고부위
# 0            1  2022-0291538  일반학생   운동장        체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생   운동장        체육시간          발목
# 2            3  2022-0306043  일반학생   운동장          기타          발목
# 5            6  2022-0383474  일반학생   운동장        체육시간          기타
# 6            7  2022-0378848  일반학생  놀이시설        일반수업     아래팔,팔꿈치
# ...        ...           ...   ...   ...         ...         ...
# 545957  545770  2018-0145030  일반학생   운동장  방과후 교실(활동)           손
# 545959  545772  2018-0145037  일반학생  일반교실        휴식시간          두피
# 545961  545774  2018-0145052  일반학생  일반교실        점심시간          두피
# 545962  545775  2018-0145062  일반학생    복도        휴식시간           발
# 545964  545777  2018-0145066  일반학생   운동장        휴식시간          치아
#
#                     사고형태                               매개물  사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)      기타  \
# ...

# %%
신분류_사고형태_df.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/신분류_사고형태_df.csv', encoding='utf-8', index=False)

# %%
all_df_not_nan=df10.dropna(subset=['신분류_매개물','신분류_사고당시활동','신분류_사고시간','신분류_사고장소','신분류_사고형태'])

# %%
all_df_nan = df10[
    (df10['신분류_매개물'].isna()) & 
    (df10['신분류_사고당시활동'].isna()) & 
    (df10['신분류_사고시간'].isna()) & 
    (df10['신분류_사고장소'].isna()) & 
    (df10['신분류_사고형태'].isna())
]

# %%
all_df_nan.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/all_df_nan.csv', encoding='utf-8', index=False)

# %%
#df10.to_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/df10.csv",index=True, encoding='utf-8-sig')

# %%
사고부위_0=set()

for index, row in df10.iterrows():
    if ',' not in row['사고부위']:
        사고부위_0.add(row['사고부위'])

# %%
사고부위_0
# Out:
# {'겨드랑이',
#  '견갑골',
#  '귀',
#  '기타',
#  '내장기관',
#  '넓적다리(허벅지)',
#  '눈',
#  '대퇴골',
#  '두피',
#  '등',
#  '목',
#  '무릎',
#  '발',
#  '발가락',
#  '발목',
#  '배',
#  '볼',
#  '불상',
#  '손',
#  '손가락',
#  '손목',
#  '쇄골',
#  '신경계',
#  '아래다리',
#  '아래팔',
#  '어깨',
#  '엉덩이',
#  '위팔',
#  '이마',
#  '입(구강/혀)',
#  '종아리',
#  '치아',
#  '코',
#  '턱',
#  '팔꿈치',
#  '허리',
#  '흉부(가슴)'}

# %%
#사고부위_2=set()

#for index, row in df10.iterrows():
#    if '발' in row['사고부위']:
#        사고부위_2.add(row['사고부위'])

# %%
#사고부위_2

# %%
#구분류 
conditions = [
    df9['사고부위'] == '겨드랑이',#1
    df9['사고부위'] == '견갑골',#2
    df9['사고부위'] == '기타',#3
    df9['사고부위'] == '내장기관',#4
    df9['사고부위'] == '넓적다리(허벅지)',#5
    df9['사고부위'] == '눈',#6
    df9['사고부위'] == '대퇴골',#7
    df9['사고부위'] == '두피',#8
    df9['사고부위'] == '등',#9
    df9['사고부위'] == '목',#10
    df9['사고부위'] == '무릎',#11
    df9['사고부위'] == '발',#12
    df9['사고부위'] == '발가락',#13
    df9['사고부위'] == '발목',#14
    df9['사고부위'] == '배',#15
    df9['사고부위'] == '볼',#16
    df9['사고부위'] == '불상',#17
    df9['사고부위'] == '손',#18
    df9['사고부위'] == '손가락',#19
    df9['사고부위'] == '손목',#20
    df9['사고부위'] == '쇄골',#21
    df9['사고부위'] == '신경계',#22
    df9['사고부위'] == '아래다리',#23
    df9['사고부위'] == '아래팔',#24
    df9['사고부위'] == '어깨',#25
    df9['사고부위'] == '엉덩이',#26
    df9['사고부위'] == '위팔',#27
    df9['사고부위'] == '이마',#28
    df9['사고부위'] == '입(구강/혀)',#29
    df9['사고부위'] == '종아리',#30
    df9['사고부위'] == '치아',#31
    df9['사고부위'] == '코',#32
    df9['사고부위'] == '턱',#33
    df9['사고부위'] == '팔꿈치',#34
    df9['사고부위'] == '허리',#35
    df9['사고부위'] == '흉부(가슴)',#36
    ]


#신분류
values = ['몸통-흉복부-흉부',#1
        '몸통-등‧허리-등',#2
        '기타-기타-기타',#3
        '몸통-흉복부-내장기관',#4
        '사지-다리-넓적다리(허벅지)',#5
        '머리와 목-머리(입 제외)-눈',#6
        '사지-다리-넓적다리(허벅지)',#7
        '머리와 목-머리(입 제외)-두피',#8
        '몸통-등‧허리-등',#9
        '머리와 목-목-목',#10
        '사지-다리-무릎',#11
        '사지-발목 및 발가락-발',#12
        '사지-발목 및 발가락-발가락',#13
        '사지-발목 및 발가락-발목',#14
        '몸통-흉복부-복부',#15
        '머리와 목-머리(입 제외)-볼',#16
        '기타-기타-기타',#17
        '사지-손목 및 손-손',#18
        '사지-손목 및 손-손가락',#19
        '사지-손목 및 손-손목',#20
        '사지-팔-위팔',#21 #쇄골
        '기타-기타-기타',#22
        '사지-다리-아래다리(종아리)',#23
        '사지-팔-아래팔',#24
        '사지-팔-어깨',#25
        '사지-다리-골반/엉덩이',#26
        '사지-팔-위팔',#27
        '머리와 목-머리(입 제외)-이마',#28
        '머리와 목-입-입술 및 구강',#29
        '사지-다리-아래다리(종아리)',#30
        '머리와 목-입-치아',#31
        '머리와 목-머리(입 제외)-코',#32
        '머리와 목-머리(입 제외)-턱',#33
        '사지-팔-팔꿈치',#34
        '몸통-등‧허리-허리',#35
        '몸통-흉복부-흉부'#36
        ]

df10['신분류_사고부위2'] = np.select(conditions, values, default=np.NaN)

# %%
df10
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
df10['신분류_사고부위3']=df10['신분류_사고부위'].fillna('').replace('nan', '')+df10['신분류_사고부위2'].fillna('').replace('nan', '')

# %%
df10
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
uni = df10['신분류_사고부위3'].unique()
uni
# Out:
# array(['복합부위-복합부위-복합부위', '사지-발목 및 발가락-발목', '사지-손목 및 손-손목',
#        '사지-손목 및 손-손가락', '기타-기타-기타', '머리와 목-머리(입 제외)-이마',
#        '사지-다리-아래다리(종아리)', '사지-발목 및 발가락-발가락', '몸통-흉복부-복부', '사지-손목 및 손-손',
#        '사지-발목 및 발가락-발', '머리와 목-머리(입 제외)-두피', '머리와 목-머리(입 제외)-눈',
#        '머리와 목-머리(입 제외)-코', '머리와 목-머리(입 제외)-턱', '사지-다리-무릎', '사지-팔-팔꿈치',
#        '머리와 목-입-입술 및 구강', '몸통-등‧허리-허리', '머리와 목-입-치아', '',
#        '머리와 목-머리(입 제외)-볼', '사지-팔-어깨', '머리와 목-목-목', '몸통-흉복부-흉부',
#        '사지-팔-아래팔', '사지-팔-위팔', '사지-다리-넓적다리(허벅지)', '몸통-등‧허리-등',
#        '사지-다리-골반/엉덩이', '몸통-흉복부-내장기관'], dtype=object)

# %%
df10.columns
# Out:
# Index(['id', '사고번호', '사고자구분', '사고장소', '사고시간', '사고부위', '사고형태', '매개물', '사고당시활동',
#        '사고내용', '지도내용', '조치내용', '그밖의사항', '신분류_사고장소', '학교', '학교-사고시간',
#        '신분류_사고시간', '사고시간 참고용2', '신분류_사고당시활동', '신분류_매개물', '신분류_사고형태',
#        '신분류_사고부위', '신분류_사고부위2', '신분류_사고부위3'],
#       dtype='object')

# %%
uni = df10['사고당시활동'].unique()
uni
# Out:
# array(['기타', '배드민턴', '보행/주행', '식사/수면/휴식', '탑승/승선/자전거타기(운전)', '수영',
#        '장난/놀이', '실험/실습', '오래달리기', '매트운동', '공부', '배구', '싸움', '도지볼(피구)족구',
#        '야구', '축구', '농구', '무용', '단거리', '기구체조(철봉/링/평균대)', '핸드볼', '높이뛰기',
#        '탁구', '멀리뛰기', '테니스', '장애물', '스키/스케이트(인라인 포함)', '유도', '태권도',
#        '체육 기타', '구기 기타', '육상 기타', '무도 기타', '장난, 놀이', '식사, 수면, 휴식',
#        '보행, 주행', '도지볼(피구), 족구', '실험, 실습', '탑승, 승선, 자전거타기(운전)',
#        '스키, 스케이트(인라인 포함)', '기구체조(철봉, 링, 평균대)'], dtype=object)

# %%
df10.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/all_df11_total.csv', encoding='utf-8', index=False)

# %%
df11=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/all_df11_total.csv")
# Out:
# /tmp/ipykernel_24232/3916188186.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df11=pd.read_csv("/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/all_df11_total.csv")

# %%
df11
# Out:
#             id          사고번호 사고자구분       사고장소  사고시간        사고부위
# 0            1  2022-0291538  일반학생        운동장  체육시간  입(구강/혀),기타  \
# 1            2  2022-0375171  일반학생        운동장  체육시간          발목
# 2            3  2022-0306043  일반학생        운동장    기타          발목
# 3            4  2022-0292171  일반학생       체육시설  체육시간          손목
# 4            5  2022-0379283  일반학생    강당(체육관)  체육시간         손가락
# ...        ...           ...   ...        ...   ...         ...
# 545963  545776  2018-0145064  일반학생    교실 - 기타  점심시간          무릎
# 545964  545777  2018-0145066  일반학생        운동장  휴식시간          치아
# 545965  545778  2018-0145074  일반학생  부속시설 - 기타  체육시간           발
# 545966  545779  2018-0145080  일반학생         계단    하교           발
# 545967  545780  2018-0145085  일반학생       일반교실  휴식시간           발
#
#                     사고형태                               매개물       사고당시활동
# 0               넘어짐-콘크리트                   건물(문/창문/바닥/벽 등)           기타  \
# ...

# %%
selected_df11= df11[['id', '사고번호','신분류_사고장소','신분류_사고시간','신분류_사고당시활동', '신분류_매개물','신분류_사고형태', '신분류_사고부위3']]

# %%
selected_df11.to_csv('/home/fs-ai/Desktop/Woojin_Kim/NLP_text classification/School/clean_data_V0.1/selected_df11.csv', encoding='utf-8', index=False)

# %%
selected_df11
# Out:
#             id          사고번호                   신분류_사고장소
# 0            1  2022-0291538             교내-체육·집회공간-운동장  \
# 1            2  2022-0375171             교내-체육·집회공간-운동장
# 2            3  2022-0306043             교내-체육·집회공간-운동장
# 3            4  2022-0292171      교내-체육·집회공간-기타 체육·집회공간
# 4            5  2022-0379283         교내-체육·집회공간-강당(체육관)
# ...        ...           ...                        ...
# 545963  545776  2018-0145064             교내-기타 교내-기타 교내
# 545964  545777  2018-0145066             교내-체육·집회공간-운동장
# 545965  545778  2018-0145074                        NaN
# 545966  545779  2018-0145080                 교내-공용공간-계단
# 545967  545780  2018-0145085  교내-교수학습 및 학습지원공간-일반(교과)교실
#
#                               신분류_사고시간                    신분류_사고당시활동
# 0                 교육과정-교과(초·중·고)-체육-체육                           NaN  \
# 1                 교육과정-교과(초·중·고)-체육-체육                           NaN
# 2                                  NaN                           NaN
# ...
